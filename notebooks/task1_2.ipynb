# %% [markdown]
# User Overview analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
cdf = pd.read_csv('../data/clean_TellCo_data.csv')
cdf.head()
# Out:
#                Bearer Id            Start  Start ms              End  End ms  \
# 0 13114483460844900352.0   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1 13114483482878900224.0   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2 13114483484080500736.0   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3 13114483485442799616.0   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4 13114483499480700928.0  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)              IMSI  MSISDN/Number             IMEI  \
# 0  1823652.0 208201448079117.0  33664962239.0 35521209507511.0
# 1  1365104.0 208201909211140.0  33681854413.0 35794009006359.0
# 2  1361762.0 208200314458056.0  33760627129.0 35281510359387.0
# 3  1321509.0 208201402342131.0  33750343200.0 35356610164913.0
# 4  1089009.0 208201401415120.0  33699795932.0 35407009745539.0
#
#       Last Location Name  ...  Youtube DL (Bytes)  Youtube UL (Bytes)  \
# ...

# %%
# Adding two columns then creating new column and round floalt to 1 descimal places

pd.set_option('display.float_format', lambda x: '%.1f' % x)

cdf['Gaming_UL_and_DL'] = cdf['Gaming UL (Bytes)'] + cdf['Gaming DL (Bytes)']
cdf['Netflix_UL_and_DL'] = cdf['Netflix UL (Bytes)'] + cdf['Netflix DL (Bytes)']
cdf['Youtube_UL_and_DL'] = cdf['Youtube UL (Bytes)'] + cdf['Youtube DL (Bytes)']
cdf['Email_UL_and_DL'] = cdf['Email UL (Bytes)'] + cdf['Email DL (Bytes)']
cdf['Google_UL_and_DL'] = cdf['Google UL (Bytes)'] + cdf['Google DL (Bytes)']
cdf['Social Media_UL_and_DL'] = cdf['Social Media UL (Bytes)'] + cdf['Social Media DL (Bytes)']
cdf['Other_UL_and_DL'] = cdf['Other UL (Bytes)'] + cdf['Other DL (Bytes)']
cdf['Total_UL_and_DL'] = cdf['Total UL (Bytes)'] + cdf['Total DL (Bytes)']
cdf.head()
# Out:
#                Bearer Id            Start  Start ms              End  End ms  \
# 0 13114483460844900352.0   4/4/2019 12:01     770.0  4/25/2019 14:35   662.0
# 1 13114483482878900224.0   4/9/2019 13:04     235.0   4/25/2019 8:15   606.0
# 2 13114483484080500736.0   4/9/2019 17:42       1.0  4/25/2019 11:58   652.0
# 3 13114483485442799616.0   4/10/2019 0:31     486.0   4/25/2019 7:36   171.0
# 4 13114483499480700928.0  4/12/2019 20:10     565.0  4/25/2019 10:40   954.0
#
#    Dur. (ms)              IMSI  MSISDN/Number             IMEI  \
# 0  1823652.0 208201448079117.0  33664962239.0 35521209507511.0
# 1  1365104.0 208201909211140.0  33681854413.0 35794009006359.0
# 2  1361762.0 208200314458056.0  33760627129.0 35281510359387.0
# 3  1321509.0 208201402342131.0  33750343200.0 35356610164913.0
# 4  1089009.0 208201401415120.0  33699795932.0 35407009745539.0
#
#       Last Location Name  ...  Total UL (Bytes)  Total DL (Bytes)  \
# ...

# %%
# Creating new data from the cdf

clean_column = ['Bearer Id','Dur. (ms)','MSISDN/Number','Total_UL_and_DL','Other_UL_and_DL','Gaming_UL_and_DL','Netflix_UL_and_DL','Youtube_UL_and_DL','Email_UL_and_DL','Google_UL_and_DL','Social Media_UL_and_DL']
user_overview_data = cdf[clean_column]
user_overview_data.head()
# Out:
#                Bearer Id  Dur. (ms)  MSISDN/Number  Total_UL_and_DL  \
# 0 13114483460844900352.0  1823652.0  33664962239.0      345629377.0
# 1 13114483482878900224.0  1365104.0  33681854413.0      707185356.0
# 2 13114483484080500736.0  1361762.0  33760627129.0      307690973.0
# 3 13114483485442799616.0  1321509.0  33750343200.0      889352748.0
# 4 13114483499480700928.0  1089009.0  33699795932.0      607681403.0
#
#    Other_UL_and_DL  Gaming_UL_and_DL  Netflix_UL_and_DL  Youtube_UL_and_DL  \
# 0      180558843.0       292426453.0         17855187.0         18355943.0
# 1      541959383.0       609920783.0         35565545.0         39359124.0
# 2      414908351.0       229980251.0         23751202.0         34425237.0
# 3      761837216.0       810387875.0         15092588.0         36534765.0
# 4      564619822.0       531237049.0         17539799.0         34222253.0
#
#    Email_UL_and_DL  Google_UL_and_DL  Social Media_UL_and_DL
# ...

# %%
for column in clean_column:
  if(column != 'Bearer Id' and column != 'Dur. (ms)' and column != 'MSISDN/Number'):
    user_overview_data[column]= user_overview_data[column]/(10**6)
    
user_overview_data.head()
# Out:
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\3908746350.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_overview_data[column]= user_overview_data[column]/(10**6)
#                Bearer Id  Dur. (ms)  MSISDN/Number  Total_UL_and_DL  \
# 0 13114483460844900352.0  1823652.0  33664962239.0            345.6
# 1 13114483482878900224.0  1365104.0  33681854413.0            707.2
# 2 13114483484080500736.0  1361762.0  33760627129.0            307.7
# 3 13114483485442799616.0  1321509.0  33750343200.0            889.4
# 4 13114483499480700928.0  1089009.0  33699795932.0            607.7
#
#    Other_UL_and_DL  Gaming_UL_and_DL  Netflix_UL_and_DL  Youtube_UL_and_DL  \
# ...

# %%
# Grouping Using MSISDN/Number

users = user_overview_data.groupby(['MSISDN/Number'])
# Grouping the data by user and aggregating the data contained in them
aggregated_users = users.agg({'Bearer Id':'count','Dur. (ms)':'sum','Total_UL_and_DL':'sum','Other_UL_and_DL':'sum','Gaming_UL_and_DL':'sum','Netflix_UL_and_DL':'sum','Youtube_UL_and_DL':'sum','Email_UL_and_DL':'sum','Google_UL_and_DL':'sum','Social Media_UL_and_DL':'sum'})
aggregated_users['Num_of_xDR_sessions']=aggregated_users['Bearer Id']
aggregated_users.head()
# Out:
#                Bearer Id  Dur. (ms)  Total_UL_and_DL  Other_UL_and_DL  \
# MSISDN/Number
# 33601001722.0          1   116720.0            878.7            386.6
# 33601001754.0          1   181230.0            156.9            281.7
# 33601002511.0          1   134969.0            596.0            501.7
# 33601007832.0          1    49878.0            422.3             35.3
# 33601008617.0          2    37104.0           1457.4            804.8
#
#                Gaming_UL_and_DL  Netflix_UL_and_DL  Youtube_UL_and_DL  \
# MSISDN/Number
# 33601001722.0             812.5               27.2               21.6
# 33601001754.0             119.8               11.2               12.4
# 33601002511.0             538.8               19.4               21.3
# 33601007832.0             391.1                1.9                7.0
# 33601008617.0            1314.8               49.2               41.5
#
#                Email_UL_and_DL  Google_UL_and_DL  Social Media_UL_and_DL  \
# MSISDN/Number
# ...

# %% [markdown]
# Univariant Analysis: Non-graphical Univariante Analysis

# %%
# Change the data type of Bearer Id to string

aggregated_users['Bearer Id'] = aggregated_users['Bearer Id'].astype(str)
aggregated_users.dtypes
# Out:
# Bearer Id                  object
# Dur. (ms)                 float64
# Total_UL_and_DL           float64
# Other_UL_and_DL           float64
# Gaming_UL_and_DL          float64
# Netflix_UL_and_DL         float64
# Youtube_UL_and_DL         float64
# Email_UL_and_DL           float64
# Google_UL_and_DL          float64
# Social Media_UL_and_DL    float64
# Num_of_xDR_sessions         int64
# dtype: object

# %% [markdown]
# Univariate analysis concerns one single variable where as bivariant analysis involves the relationship of two variables

# %%
#Bearer Id Non-graphical univatiant analysis
aggregated_users['Bearer Id'].describe()
# Out:
# count     107901
# unique        17
# top            1
# freq       78774
# Name: Bearer Id, dtype: object

# %%
# Dur. (ms) Non-graphical uniavriant analysis
aggregated_users['Dur. (ms)'].describe()
# Out:
# count     107901.0
# mean      145423.9
# std       185733.0
# min         7142.0
# 25%        69420.0
# 50%       102020.0
# 75%       172799.0
# max     18553754.0
# Name: Dur. (ms), dtype: float64

# %%
# Total UL and DL Non-graphicahl univariant analysis
aggregated_users['Total_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean       689.2
# std        489.7
# min         33.2
# 25%        357.5
# 50%        616.4
# 75%        855.9
# max       8846.2
# Name: Total_UL_and_DL, dtype: float64

# %%
#Other UL and DL Non-graphical univariant analysis
aggregated_users['Other_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean       596.9
# std        447.8
# min          0.1
# 25%        284.6
# 50%        538.5
# 75%        773.9
# max       8167.9
# Name: Other_UL_and_DL, dtype: float64

# %%
#Gamming_UL and DL Non-graphical Univariate analysis
aggregated_users['Gaming_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean       598.2
# std        448.0
# min          0.3
# 25%        287.2
# 50%        541.1
# 75%        776.0
# max       7749.4
# Name: Gaming_UL_and_DL, dtype: float64

# %%
#Netflix_UL and DL Nongraphical univariate analysis
aggregated_users['Netflix_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean        31.5
# std         21.2
# min          0.2
# 25%         18.5
# 50%         26.7
# 75%         37.9
# max        399.5
# Name: Netflix_UL_and_DL, dtype: float64

# %%
#Youtube_UL and DL Nongraphical univariate analysis
aggregated_users['Youtube_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean        31.5
# std         21.2
# min          0.1
# 25%         18.6
# 50%         26.7
# 75%         37.8
# max        453.0
# Name: Youtube_UL_and_DL, dtype: float64

# %%
#Email_UL and DL Nongraphical univariate analysis
aggregated_users['Email_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean         3.1
# std          2.2
# min          0.0
# 25%          1.7
# 50%          2.8
# 75%          3.8
# max         42.4
# Name: Email_UL_and_DL, dtype: float64

# %%
#Google_UL and DL Nongraphical univariate analysis
aggregated_users['Google_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean        10.9
# std          7.5
# min          0.0
# 25%          5.9
# 50%          9.6
# 75%         13.2
# max        152.2
# Name: Google_UL_and_DL, dtype: float64

# %%
#Social Media_UL and DL Nongraphical univariate analysis
aggregated_users['Social Media_UL_and_DL'].describe()
# Out:
# count   107901.0
# mean         2.5
# std          1.9
# min          0.0
# 25%          1.2
# 50%          2.3
# 75%          3.3
# max         43.4
# Name: Social Media_UL_and_DL, dtype: float64

# %%
#Dur. (ms) Nongraphical univariate analysis
aggregated_users['Dur. (ms)'].describe()
# Out:
# count     107901.0
# mean      145423.9
# std       185733.0
# min         7142.0
# 25%        69420.0
# 50%       102020.0
# 75%       172799.0
# max     18553754.0
# Name: Dur. (ms), dtype: float64

# %% [markdown]
# Graphical Univariate Analysis

# %%
# Defining the plot functions
from matplotlib import pyplot as plt
def plot_univariate(df, col1, col2):
    plt.figure(figsize = (20, 15))

    plt.subplot(2, 2, 1)
    plt.hist(df[col1], bins = 20, color = 'orange', edgecolor = 'gray', linewidth = 0.5)
    plt.title(f'Histogram of {col1}', size=14)

    plt.subplot(2, 2, 2)
    plt.boxplot(df[col1])
    plt.title(f'Boxplot of {col1}', size=14)

    plt.subplot(2, 2, 3)
    plt.hist(df[col2], bins=20, color='orange', edgecolor='gray', linewidth=0.5)
    plt.title(f'Histogram of {col2}', size=14)

    plt.subplot(2, 2, 4)
    plt.boxplot(df[col2])
    plt.title(f'Boxplot of {col2}', size=14)
    
    plt.show()
# Out:
# <function __main__.plot_univariate(df, col1, col2)>

# %%
# Fixing the outliers

def fix_outlier(df, column):
    df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].median(),df[column])
    
    return df[column]

# Fixing the outliers in each column
user_overview_data['Dur. (ms)']=fix_outlier(user_overview_data,'Dur. (ms)')
user_overview_data['Gaming_UL_and_DL']=fix_outlier(user_overview_data,'Gaming_UL_and_DL')
user_overview_data['Netflix_UL_and_DL']=fix_outlier(user_overview_data,'Netflix_UL_and_DL')
user_overview_data['Youtube_UL_and_DL']=fix_outlier(user_overview_data,'Youtube_UL_and_DL')
user_overview_data['Email_UL_and_DL']=fix_outlier(user_overview_data,'Email_UL_and_DL')
user_overview_data['Google_UL_and_DL']=fix_outlier(user_overview_data,'Google_UL_and_DL')
user_overview_data['Social Media_UL_and_DL']=fix_outlier(user_overview_data,'Social Media_UL_and_DL')
user_overview_data['Other_UL_and_DL']=fix_outlier(user_overview_data,'Other_UL_and_DL')
user_overview_data['Total_UL_and_DL']=fix_outlier(user_overview_data,'Total_UL_and_DL')

user_overview_data.head()
# Out:
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1904662959.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].median(),df[column])
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1904662959.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_overview_data['Dur. (ms)']=fix_outlier(user_overview_data,'Dur. (ms)')
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1904662959.py:10: SettingWithCopyWarning:
# ...

# %%
user_overview_data['Dur. (ms)']=fix_outlier(user_overview_data,'Dur. (ms)')
user_overview_data['Gaming_UL_and_DL']=fix_outlier(user_overview_data,'Gaming_UL_and_DL')
user_overview_data['Netflix_UL_and_DL']=fix_outlier(user_overview_data,'Netflix_UL_and_DL')
user_overview_data['Youtube_UL_and_DL']=fix_outlier(user_overview_data,'Youtube_UL_and_DL')
user_overview_data['Email_UL_and_DL']=fix_outlier(user_overview_data,'Email_UL_and_DL')
user_overview_data['Google_UL_and_DL']=fix_outlier(user_overview_data,'Google_UL_and_DL')
user_overview_data['Social Media_UL_and_DL']=fix_outlier(user_overview_data,'Social Media_UL_and_DL')
user_overview_data['Other_UL_and_DL']=fix_outlier(user_overview_data,'Other_UL_and_DL')
user_overview_data['Total_UL_and_DL']=fix_outlier(user_overview_data,'Total_UL_and_DL')
user_overview_data.head()
# Out:
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1904662959.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[column] = np.where(df[column] > df[column].quantile(0.95), df[column].median(),df[column])
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1921550230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   user_overview_data['Dur. (ms)']=fix_outlier(user_overview_data,'Dur. (ms)')
# C:\Users\meron\AppData\Local\Temp\ipykernel_24880\1921550230.py:2: SettingWithCopyWarning:
# ...

# %%
# Graphical univariate analysis plots after fixing outliers

plot_univariate(user_overview_data,'Dur. (ms)','Total_UL_and_DL')
plot_univariate(user_overview_data,'Other_UL_and_DL','Gaming_UL_and_DL')
plot_univariate(user_overview_data,'Netflix_UL_and_DL','Youtube_UL_and_DL')
plot_univariate(user_overview_data,'Email_UL_and_DL','Google_UL_and_DL')
plot_univariate(user_overview_data,'Social Media_UL_and_DL','Gaming_UL_and_DL')

# %% [markdown]
# Bivariate Analysis

# %%
# Defining plotting functions

def plot_hist(df:pd.DataFrame, column:str, color:str)->None:
    # plt.figure(figsize=(15, 10))
    # fig, ax = plt.subplots(1, figsize=(12, 7))
    sns.displot(data=df, x=column, color=color, kde=True, height=7, aspect=2)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()

def plot_count(df:pd.DataFrame, column:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.countplot(data=df, x=column)
    plt.title(f'Distribution of {column}', size=20, fontweight='bold')
    plt.show()
    
def plot_bar(df:pd.DataFrame, x_col:str, y_col:str, title:str, xlabel:str, ylabel:str)->None:
    plt.figure(figsize=(12, 7))
    sns.barplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.xlabel(xlabel, fontsize=16)
    plt.ylabel(ylabel, fontsize=16)
    plt.show()

def plot_heatmap(df:pd.DataFrame, title:str, cbar=False)->None:
    plt.figure(figsize=(12, 7))
    sns.heatmap(df, annot=True, cmap='viridis', vmin=0, vmax=1, fmt='.2f', linewidths=.7, cbar=cbar )
    plt.title(title, size=18, fontweight='bold')
    plt.show()

def plot_box(df:pd.DataFrame, x_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.show()

def plot_box_multi(df:pd.DataFrame, x_col:str, y_col:str, title:str) -> None:
    plt.figure(figsize=(12, 7))
    sns.boxplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(rotation=75, fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()

def plot_scatter(df: pd.DataFrame, x_col: str, y_col: str, title: str) -> None:
    plt.figure(figsize=(12, 7))
    sns.scatterplot(data = df, x=x_col, y=y_col)
    plt.title(title, size=20)
    plt.xticks(fontsize=14)
    plt.yticks( fontsize=14)
    plt.show()

# %%
# multivariate graph of Email vs total

plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Email_UL_and_DL", title="Total UL_DL vs Email UL_DL")

# %%
 #multivariate graph of Google vs total
plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Google_UL_and_DL", title="Total UL_DL vs Google UL_DL")

# %%
 #multivariate graph of Social media vs total
plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Social Media_UL_and_DL", title="Total UL_DL vs Social UL_DL")

# %%
#multivariate graph of Netflix vs total

plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Netflix_UL_and_DL", title="Total UL_DL vs Netflix UL_DL")

# %%
#multivariate graph of Youtube vs total
plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Youtube_UL_and_DL", title="Total UL_DL vs Youtube UL_DL")

# %%
#multivariate graph of Gaming vs total

plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Gaming_UL_and_DL", title="Total UL_DL vs Gaming UL_DL")

# %%
#multivariate graph of Other vs total

plot_scatter(user_overview_data.sample(300), x_col="Total_UL_and_DL", y_col="Other_UL_and_DL", title="Total UL_DL vs Other UL_DL")
